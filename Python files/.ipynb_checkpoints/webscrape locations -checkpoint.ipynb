# %%
import numpy as np
import pandas as pd
import geopandas as gpd
# webscraping
import json
import urllib
from bs4 import BeautifulSoup
from urllib.request import urlopen
import os

# %%
path = os.getcwd()
home_path = os.path.dirname(path)
gis_folder = f'{home_path}\\GIS'
data_folder = f'{home_path}\\Data'

# %%
website_us = "https://waterservices.usgs.gov/nwis/site/?format=rdb&sites="

# %%
end = "&siteOutput=expanded&siteStatus=all"

# %%
ids = np.loadtxt(f'{data_folder}\\station_ids.txt',dtype=int)
ids
# Out:
# array([131199050,   1312000,   1315000,   1315170,   1315226,   1315227,
#          1315500,   1318500,   1327500,   1327750,   1328770,   1329490,
#          1329500,   1330000,   1330500,   1334500,   1335754,   1335755,
#          1358000,   1359133,   1359135,   1359528,   1359750,   1360640,
#          1361000,   1361200,   1362090,   1362192, 136219503,  13621955,
#          1362200,   1362230,   1362297, 136230002,   1362322,   1362336,
#          1362342,   1362357,   1362368,   1362370,   1362380,   1362465,
#          1362487,   1362497,   1362500,   1363382,   1363556,   1364500,
#          1372051,   1372500, 137449480,   1374505,   1374531,   1374559,
#          1374581,   1374598, 137462010,   1374654,   1374701,   1374781,
#          1374821,   1374890,   1374901,   1374918,   1374930,   1374941,
#          1374976,   1374987, 137499350,   1375000])

# %%
# coords_lst = []
df_lst = []
for i in ids:
    site = website_us + f'0{i}' + end
    page = urlopen(site)
    html_bytes = page.read()
    html = html_bytes.decode("utf-8")
    splitted = html[2297:].split("\n")
    header = splitted[0].split('\t')
    data = splitted[2].split('\t')
    df_lst.append(pd.DataFrame(data=[data],columns=header))
df_stations = pd.concat(df_lst)

# %%
df_stations.reset_index(drop=True,inplace=True)

# %%
gdf_station = gpd.GeoDataFrame(data=df_stations, 
                 geometry=gpd.points_from_xy(df_stations.dec_long_va,df_stations.dec_lat_va,crs="EPSG:4326"))

# %%
gdf_station
# Out:
#    agency_cd     site_no                                         station_nm  \
# 0       USGS  0131199050  FISHING BROOK (COUNTY LINE FLOW OUTLET) NR NEW...
# 1       USGS    01312000                       HUDSON RIVER NEAR NEWCOMB NY
# 2       USGS    01315000                   INDIAN RIVER NEAR INDIAN LAKE NY
# 3       USGS    01315170                    DURGIN BROOK AT BOREAS RIVER NY
# 4       USGS    01315226    VANDERWHACKER BROOK TRIB 1 NEAR BOREAS RIVER NY
# ..       ...         ...                                                ...
# 65      USGS    01374941              MUSCOOT RIVER BELOW DAM AT AMAWALK NY
# 66      USGS    01374976            ANGLE FLY BROOK AT WHITEHALL CORNERS NY
# 67      USGS    01374987                   KISCO RIVER BELOW MOUNT KISCO NY
# 68      USGS  0137499350                  HUNTER BROOK SOUTH OF YORKTOWN NY
# 69      USGS    01375000  CROTON R AT NEW CROTON DAM NR CROTON-ON-HUDSON NY
#
#    site_tp_cd    lat_va    long_va   dec_lat_va   dec_long_va coord_meth_cd  \
# 0          ST  435838.6  0741613.5  43.97738889   -74.2704167             N
# 1          ST  435757.7  0740753.0  43.96602778  -74.13138889             N
# 2          ST  434523.4  0741601.4      43.7565   -74.2670556             N
# 3          ST  435623.4  0735713.0   43.9398333   -73.9536111             G
# 4          ST  435654.6  0735918.1      43.9485   -73.9883611             G
# ..        ...       ...        ...          ...           ...           ...
# 65         ST  411715.4  0734513.1   41.2876111  -73.75363889             M
# 66         ST  411657.1  0734331.6  41.28252778   -73.7254444             M
# 67         ST  411343.5  0734437.0     41.22875   -73.7436111             M
# 68         ST    411543    0735034  41.26194444  -73.84277778             M
# 69         ST  411330.1  0735132.0  41.22502778  -73.85888889             D
#
#    coord_acy_cd  ... reliability_cd gw_file_cd nat_aqfr_cd aqfr_cd  \
# 0             1  ...                         Y
# 1             1  ...                  NNNNNNNN
# 2             1  ...                  NNNNNNNN
# 3             1  ...
# 4             1  ...
# ..          ...  ...            ...        ...         ...     ...
# 65            1  ...                  NNNNNNNN
# 66            1  ...                  NNNNNNNN
# 67            1  ...                  NNNNNNNN
# 68            S  ...                  NNNNNNNN
# 69            1  ...                  NNNNNNNN
#
#    aqfr_type_cd well_depth_va hole_depth_va depth_src_cd project_no  \
# 0                                                         GAZETTEER
# 1
# 2
# 3                                                            WECASS
# 4                                                            WECASS
# ..          ...           ...           ...          ...        ...
# 65
# 66
# 67
# 68
# 69
#
#                       geometry
# 0   POINT (-74.27042 43.97739)
# 1   POINT (-74.13139 43.96603)
# 2   POINT (-74.26706 43.75650)
# 3   POINT (-73.95361 43.93983)
# 4   POINT (-73.98836 43.94850)
# ..                         ...
# 65  POINT (-73.75364 41.28761)
# 66  POINT (-73.72544 41.28253)
# 67  POINT (-73.74361 41.22875)
# 68  POINT (-73.84278 41.26194)
# 69  POINT (-73.85889 41.22503)
#
# [70 rows x 43 columns]

# %%
gdf_station.to_file(f"{gis_folder}\\discharge_stations.gpk", driver="GPKG")
