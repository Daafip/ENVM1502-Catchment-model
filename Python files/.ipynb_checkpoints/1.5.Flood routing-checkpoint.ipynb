# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
import datetime
import math
from scipy.optimize import root
import glob
import os

# %%
def c0(x, dt, k):
    return (-2 * x + (dt / k)) / (2 * (1 - x) + (dt / k))
            
def c1(x, dt, k):
    return (2 * x + (dt / k)) / (2 * (1 - x) + (dt / k))

def c2(x, dt, k):
    return (2 * (1 - x) - (dt / k)) / (2 * (1 - x) + (dt / k))

def combine(x, dt, k):
    c_0, c_1, c_2 = c0(x, dt, k), c1(x, dt, k), c2(x, dt, k)
    if math.isclose(c_0 + c_1 + c_2, 1):
        return c_0, c_1, c_2
    else:
        raise warnings.warn(f"Issue with coding: {c_0}, {c_1}, {c_2} = {c_0+ c_1 +c_2}")
    
def prev_date(date, days=1):    
    "function to get prev timestep"
    subtracted_date = pd.to_datetime(date) - datetime.timedelta(days=days)
    subtracted_date = subtracted_date.strftime("%Y-%m-%d")
    return subtracted_date

# %%
def obj(params, data, return_df=False):
    x, k = params
    df, dt = data[0], data[1]
    c_0, c_1, c_2 = combine(x, dt, k)
    
    for i, date in enumerate(df.index):
        if i == 0:
            pass
        else:
            day_before = prev_date(date, days=dt)
            if (day_before in df.index):
                i1 = df.loc[day_before,"I"]  # inflow timestep before
                o1 = df.loc[day_before, "O"] # outflow timestep before
                i2 = df.loc[date, "I"]
                o2 = c_0 * i2 + c_1 * i1 + c_2 * o1
                df.loc[date, "Qm"] = o2
                df.loc[date, "RMSE"] = (df.loc[date, "Qm"] - df.loc[date, "O"])**2
            else:
                pass
    RMSE_sum = np.sqrt(df["RMSE"].sum())/ (len(df["RMSE"].dropna()))
    if return_df:
        return df
    return RMSE_sum,RMSE_sum

# %%
path = os.getcwd()
home_path = os.path.dirname(path)
data_folder = f'{home_path}\\Data'
files = glob.glob(f"{data_folder}\\Q\\*.parquet")

# %%
# the flows have been added in m^3/s then divided by the total area
df_combined_E_W_path = glob.glob(f"{data_folder}\\Q\\combining_1357500_1335754.parquet")

df_combined_E_W = pd.read_parquet(df_combined_E_W_path[0], columns=['Q_m3_s_mean','date', 'Q_mm_d_hydro'])
df_combined_E_W.index = pd.to_datetime(df_combined_E_W.date)
df_combined_E_W.rename(columns={'Q_mm_d_hydro':'Q'}, inplace=True)

# %%
id_up = '1346000'
file_up  = glob.glob(f"{data_folder}\\Q\\*{id_up}.parquet")
df_up = pd.read_parquet(file_up, columns=['Q_m3_s_mean']).dropna().rename(columns={'Q_m3_s_mean':'I'})
df_dw = df_combined_E_W.dropna().rename(columns={'Q_m3_s_mean':'O'})
df_dw.index =  df_dw.index.astype('datetime64[ns]')
df_up.index =  df_up.index.astype('datetime64[ns]')

# %%
dt = 1
df = pd.concat([df_up.loc['1996':'2000'], df_dw.loc['1996':'2000']],axis=1).dropna()
data = [df, dt]
params = [0.2, 1]

# %%
output = root(obj,(0.1, 1), args=(data))
output
# Out:
#     fjac: array([[-0.70710678, -0.70710678],
#        [ 0.70710678, -0.70710678]])
#      fun: array([4.32068638, 4.32068638])
#  message: 'The iteration is not making good progress, as measured by the \n  improvement from the last ten iterations.'
#     nfev: 25
#      qtf: array([-6.11204456e+00,  1.52099257e-12])
#        r: array([-1.57678395e-03, -4.01500426e-04,  1.08420217e-19])
#   status: 5
#  success: False
#        x: array([-6.45182196,  2.88674591])

# %%
fig, ax = plt.subplots(1)
df_out = obj(output.x, data, return_df=True)[[ "I","Qm", "O"]]
df_out.plot(ax=ax)
ax.set_xlabel('Date')
ax.set_ylabel('Discharge [m3/s]')
ax.set_title("Modeled vs Actual Discharge Peak")
ax.legend(["Previous station", "Modelled","Measured"])

# %%
df_out = obj(output.x, data, return_df=True)[[ "I","Qm", "O"]]
# Out:
# <Axes: xlabel='datetime'>

# %%
fig, ax = plt.subplots(1)
df_out.plot(ax=ax)
ax.set_xlabel('Date')
ax.set_ylabel('Discharge [m3/s]')
ax.set_title("Modeled vs Actual Discharge Peak between 1996 & 2000")
ax.legend(["Previous station", "Modelled","Measured"])
ax.set_xlim(("1996","2000"))
fig.savefig("Figures/moddeld_vs_measure_muskin_routing.png")
