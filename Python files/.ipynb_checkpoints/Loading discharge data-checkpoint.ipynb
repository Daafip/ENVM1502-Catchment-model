# %%
import numpy as np
import pandas as pd
import os
import glob

# %%
path = os.getcwd()
home_path = os.path.dirname(path)
data_folder = f'{home_path}\\Data'

# %%
files = glob.glob(f"{data_folder}\\*.txt")
files
# Out:
# ['C:\\Users\\david\\Documents\\@@ Python\\Jaar 5\\Q3\\ENVM1502\\Git\\ENVM1502-Catchment-model\\Data\\120_days_01310521.txt',
#  'C:\\Users\\david\\Documents\\@@ Python\\Jaar 5\\Q3\\ENVM1502\\Git\\ENVM1502-Catchment-model\\Data\\2007-2010_01310521.txt']

# %%
pd.read_csv(files[0],delimiter="	",skiprows=[i for i in range(28)] + [29])
# Out:
#       agency_cd  site_no          datetime tz_cd  106564_62619  \
# 0          USGS  1310521  2022-11-22 00:00   EST         -1.77
# 1          USGS  1310521  2022-11-22 00:06   EST         -1.76
# 2          USGS  1310521  2022-11-22 00:12   EST         -1.77
# 3          USGS  1310521  2022-11-22 00:18   EST         -1.78
# 4          USGS  1310521  2022-11-22 00:24   EST         -1.76
# ...         ...      ...               ...   ...           ...
# 28831      USGS  1310521  2023-03-22 03:06   EST         -1.44
# 28832      USGS  1310521  2023-03-22 03:12   EST         -1.33
# 28833      USGS  1310521  2023-03-22 03:18   EST         -1.23
# 28834      USGS  1310521  2023-03-22 03:24   EST         -1.12
# 28835      USGS  1310521  2023-03-22 03:30   EST         -1.01
#
#       106564_62619_cd  238970_62620 238970_62620_cd
# 0                   A         -2.91               P
# 1                   A         -2.90               P
# ...

# %% [markdown]
# https://waterservices.usgs.gov/nwis/iv/?sites=01327750&parameterCd=00060&startDT=2023-03-15T05:45:18.716-04:00&endDT=2023-03-22T05:45:18.716-04:00&siteStatus=all&format=rdb
